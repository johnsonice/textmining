# %%
import gensim
from sklearn.model_selection import train_test_split  
import numpy as np
import glob
import os

# %% [markdown]
# ### Data pre-process

# %%
data_path = '../../imdb'
train_pos_path = os.path.join(data_path,'train','pos')
train_neg_path = os.path.join(data_path,'train','neg')
train_unsup_path = os.path.join(data_path,'train','unsup')

# %%
def read_text(path):
    files = glob.glob(path+'/*.txt')
    sentances = list()
    for fi in files:
        with open(fi) as f:
            text = f.read()
        sentances.append(text)
    return sentances

# %%
train_pos_reviews = read_text(train_pos_path)
train_neg_reviews = read_text(train_neg_path)
train_unsup_reviews = read_text(train_unsup_path)

# %%
def clean_text(corpus):
    punctuation = """.,?!:;(){}[]"""
    corpus = [z.lower().replace('\n','') for z in corpus]
    corpus = [z.replace('<br />', ' ') for z in corpus]
    
    # treat punctuation as individual words 
    for c in punctuation:
        corpus = [z.replace(c, ' %s '%c) for z in corpus]
    corpus = [z.split() for z in corpus]
    return corpus

# %%
x = np.concatenate((train_pos_reviews, train_neg_reviews),axis=0)
y = np.concatenate((np.ones(len(train_pos_reviews)), np.zeros(len(train_neg_reviews))))
x= clean_text(x)

# %%
len(x)
# Out:
# 25000

# %% [markdown]
# ### Now we can do doc2vect model

# %%
from gensim import corpora, models
from gensim.models.doc2vec import TaggedDocument
import random
from gensim.models import Doc2Vec
#LabeledSentence = gensim.models.doc2vec.LabeledSentence

# %% [markdown]
# label all sentances

# %%
def read_corpus(reviews):
    for i,doc in enumerate(reviews):
        yield TaggedDocument(doc,[i])

train_corpus = list(read_corpus(x))

# %%
cores = os.cpu_count()
size = 300
window = 10

model = Doc2Vec(size=size, min_count=4, window =window,iter=50)
model.build_vocab(train_corpus)
model.train(train_corpus, total_examples=model.corpus_count, epochs=model.iter)
# Out:
# 229839184

# %%
model.save('../../reviews.d2v')

# %%
model.docvecs.most_similar([now_doc],topn=10)
# Out:
# [(19237, 0.6252765655517578),
#  (10212, 0.6087512969970703),
#  (23786, 0.6073160767555237),
#  (4257, 0.5982194542884827),
#  (21356, 0.5819867849349976),
#  (1090, 0.5811036229133606),
#  (11509, 0.5805668234825134),
#  (19927, 0.572235643863678),
#  (19059, 0.5641859173774719),
#  (1546, 0.5593593120574951)]

# %%
now_doc = model.infer_vector('this is a very interesting'.split())

# %%
now_doc
# Out:
# array([-0.10814448,  0.10383542, -0.0092326 , -0.09356308, -0.01124847,
#        -0.03740203,  0.01803833, -0.05689717, -0.09740145, -0.04742213,
#         0.06144497, -0.0207079 ,  0.08344452, -0.0102215 ,  0.01805961,
#        -0.0563374 , -0.03795331, -0.02004271,  0.00814117,  0.00222164,
#        -0.01514807, -0.05275096,  0.01659757, -0.05877526,  0.00673218,
#        -0.24246559,  0.07701737, -0.13610932, -0.09650938,  0.03345409,
#        -0.04590155, -0.22094624,  0.04422341, -0.09393533,  0.14385749,
#         0.00740965,  0.09581789, -0.04488746,  0.01246224, -0.15887953,
#        -0.00963537, -0.04535013, -0.07856664, -0.04914945, -0.05787019,
#        -0.42161831, -0.49123573,  0.72197944, -2.03579235,  0.68073285,
#         0.46903315, -0.70698494,  0.64072031, -0.87492174,  0.98321748,
#         0.31174344, -0.9516862 , -0.17963549,  0.21291639,  0.23816793,
#         0.82232922,  0.16451614,  0.2820009 , -0.25541964, -0.1072603 ,
#         1.55325651,  0.9763124 , -0.3546057 ,  1.69022179,  0.77834964,
#         0.32022858, -0.58920544, -0.66480416,  1.33124673,  0.33080068,
#         0.7689653 ,  1.1464268 , -0.0877177 , -0.60937542,  0.05783384,
#         0.38174483,  0.64871711,  0.72803408,  1.02569485, -0.85290211,
#         0.82245797, -0.01842227, -1.44083607, -0.36625594,  1.32051468,
#         0.35423005, -0.32284832,  0.52523422, -0.43717512,  0.30299047,
#         0.69446158,  0.8143484 , -0.1099842 ,  0.66928953, -0.90335298,
#         0.4091334 ,  0.83969671,  0.45466962, -0.76197708, -1.17202115,
#         0.23745313, -0.46633941,  0.87709832, -0.08609758,  1.01609302,
#        -0.97759461, -0.40351862, -0.50676608, -0.9587518 , -0.6122756 ,
#        -1.40437376,  0.64192796,  0.93209416,  0.930857  , -0.29319695,
#         0.16112807,  0.16260482,  0.96162277,  1.28297794,  0.07808904,
#         0.43003017, -0.38961127,  0.90278333,  0.4448413 , -0.588103  ,
#        -0.23054144,  1.18369961,  1.15452588, -1.69729447, -0.14523625,
#         1.31515098, -0.17087159,  1.14716554,  1.39547217, -0.06571637,
#         0.09280419,  1.17710209,  0.53710836,  0.20755279,  2.3799746 ,
#        -0.96785581, -1.10713899,  0.43808782,  0.52628481, -0.47885054,
#        -0.71108598,  0.91737896, -0.45885748,  1.64264393, -0.23429357,
#         0.11689112, -0.54749978, -0.9057287 ,  0.60649818,  0.86100364,
#         0.02603433,  0.73454547, -0.5425899 ,  0.44067693, -0.01539969,
#        -0.15570579,  1.16277504,  0.0676932 , -0.92083067, -0.29363573,
#        -0.02600638,  0.80693597, -0.47204849,  0.26183712, -1.54640532,
#        -0.48642343,  1.05923915, -1.38599598,  0.64809304,  0.71676654,
#        -0.14137544,  0.54781979, -0.54813838,  0.73136753, -0.47879568,
#        -1.16993058, -1.45187187, -0.76161045,  0.7830351 , -0.81017917,
#         0.47307682, -0.30944258, -0.4891791 ,  0.19048853, -0.26292855,
#        -0.01593378, -0.14266486, -0.25400689, -1.25373828, -0.00752976,
#        -0.71680903, -0.46117079, -1.99784875, -0.55142564,  0.07557795], dtype=float32)

# %%
model.docvecs.most_similar(1)
# Out:
# [(8105, 0.46626079082489014),
#  (19927, 0.43985748291015625),
#  (6419, 0.4132939279079437),
#  (14796, 0.4051125943660736),
#  (14649, 0.399934321641922),
#  (7059, 0.39813166856765747),
#  (5489, 0.3968348205089569),
#  (17792, 0.39266782999038696),
#  (9992, 0.3916124701499939),
#  (286, 0.3911878168582916)]

# %%
gensim.similarity(now_doc,model.docvecs[1])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-40-6745739ec81b> in <module>()
# ----> 1 gensim.similarity(now_doc,model.docvecs[1])
#
# AttributeError: module 'gensim' has no attribute 'similarity'
